# %% [markdown]
# # Constructing Kuala Lumpur Main Area

# %%
# !pip install beautifulsoup4
##parse html
# !pip install lxml 
# !pip install html5lib
#request library
# !pip install requests
# !pip install bingmaps
# !pip install geopy
# !pip install folium
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\ukitake\anaconda3.1\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\ukitake\anaconda3.1\lib\site-packages (from beautifulsoup4) (1.9.5)
# Requirement already satisfied: lxml in c:\users\ukitake\anaconda3.1\lib\site-packages (4.5.0)
# Requirement already satisfied: html5lib in c:\users\ukitake\anaconda3.1\lib\site-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in c:\users\ukitake\anaconda3.1\lib\site-packages (from html5lib) (1.14.0)
# Requirement already satisfied: webencodings in c:\users\ukitake\anaconda3.1\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: requests in c:\users\ukitake\anaconda3.1\lib\site-packages (2.9.1)
# Requirement already satisfied: bingmaps in c:\users\ukitake\anaconda3.1\lib\site-packages (0.3.7)
# Requirement already satisfied: marshmallow==2.6.0 in c:\users\ukitake\anaconda3.1\lib\site-packages (from bingmaps) (2.6.0)
# Requirement already satisfied: requests==2.9.1 in c:\users\ukitake\anaconda3.1\lib\site-packages (from bingmaps) (2.9.1)
# Requirement already satisfied: xmltodict==0.10.1 in c:\users\ukitake\anaconda3.1\lib\site-packages (from bingmaps) (0.10.1)
# Requirement already satisfied: geopy in c:\users\ukitake\anaconda3.1\lib\site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\ukitake\anaconda3.1\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium in c:\users\ukitake\anaconda3.1\lib\site-packages (0.11.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ukitake\anaconda3.1\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\ukitake\anaconda3.1\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: numpy in c:\users\ukitake\anaconda3.1\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: requests in c:\users\ukitake\anaconda3.1\lib\site-packages (from folium) (2.9.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ukitake\anaconda3.1\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)

# %% [markdown]
# ### 1. Import the necessary package

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from bingmaps.apiservices import LocationByAddress
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # for map randering
import numpy as np # library to handle data in a vectorized manner
from sklearn.cluster import KMeans
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import json

# %% [markdown]
# For this purpose, we will utilise Bing Map API

# %%
#bing Map key
bmkey='xxxx'

# %% [markdown]
# ### 2. Set parameter and inititate web scraping using pandas looking for table

# %% [markdown]
# For this purpose, we will utilize dataset from oour github member where he has 2,884 long list of roads in Kuala Lumpur. However, for our purposes, we want to find the main area in Kuala Lumpur only. Thus, this data needs to be trimmed down.

# %%
url='https://raw.githubusercontent.com/heiswayi/malaysia-postcodes/master/kuala_lumpur.csv'

# %%
df = pd.read_csv(url)
print(df.shape)
df
# Out:
# (2884, 4)
#       POSTCODE                      ADDRESS          CITY STATE
# 0        50000        Bangunan Bangkok Bank  Kuala Lumpur   KUL
# 1        50000            Jalan Balai Polis  Kuala Lumpur   KUL
# 2        50000                 Jalan Bandar  Kuala Lumpur   KUL
# 3        50000             Jalan Cheng Lock  Kuala Lumpur   KUL
# 4        50000             Jalan Hang Lekir  Kuala Lumpur   KUL
# ...        ...                          ...           ...   ...
# 2879     60000      Medan Burhanuddin Helmi  Kuala Lumpur   KUL
# 2880     60000   Persiaran Abang Haji Openg  Kuala Lumpur   KUL
# 2881     60000  Persiaran Burhanuddin Helmi  Kuala Lumpur   KUL
# 2882     60000                Pinggir Zaaba  Kuala Lumpur   KUL
# 2883     60000          Taman Tun Dr Ismail  Kuala Lumpur   KUL
#
# [2884 rows x 4 columns]

# %% [markdown]
# ### 3. Cleanup the data

# %% [markdown]
# We only take one postcode for each area to avoid duplication

# %%
# Remove postcode duplicates
df = df.drop_duplicates(subset=['POSTCODE'])
# Drop Address Columnn as we are not using it
df = df.drop(['ADDRESS'], axis = 1)
# Reset index
df.reset_index(drop=True, inplace=True)
df
# Out:
#      POSTCODE          CITY STATE
# 0       50000  Kuala Lumpur   KUL
# 1       50050  Kuala Lumpur   KUL
# 2       50088  Kuala Lumpur   KUL
# 3       50100  Kuala Lumpur   KUL
# 4       50150  Kuala Lumpur   KUL
# ..        ...           ...   ...
# 272     59200  Kuala Lumpur   KUL
# 273     59700  Kuala Lumpur   KUL
# 274     59800  Kuala Lumpur   KUL
# 275     59990  Kuala Lumpur   KUL
# 276     60000  Kuala Lumpur   KUL
#
# [277 rows x 3 columns]

# %% [markdown]
# We will find location (longitude and latitude) for each address using bing map

# %%
postalCode = '50050'
countryRegion = 'Malaysia'
adminDistrict = '50050 Kuala Lumpur'

code = df['POSTCODE']
code_lat=[]
code_long=[]
for i in code :
    data = {'adminDistrict': adminDistrict,'postalCode': i, 'countryRegion': countryRegion,'key': bmkey}
    loc_by_address = LocationByAddress(data)
    loc_by_address.get_coordinates
    for coord in loc_by_address.get_coordinates:
        code_lat += [coord.latitude]
        code_long += [coord.longitude]
        break        
        
df2 = pd.DataFrame (code_lat,columns=['Latitude'])
df3 = pd.DataFrame (code_long,columns=['Longitude'])


df4= df2.join(df3)
df=df.join(df4)
df
# Out:
#      POSTCODE          CITY STATE  Latitude   Longitude
# 0       50000  Kuala Lumpur   KUL  3.142934  101.696373
# 1       50050  Kuala Lumpur   KUL  3.147618  101.696281
# 2       50088  Kuala Lumpur   KUL  3.155141  101.711540
# 3       50100  Kuala Lumpur   KUL  3.152210  101.696510
# 4       50150  Kuala Lumpur   KUL  3.191760  101.658691
# ..        ...           ...   ...       ...         ...
# 272     59200  Kuala Lumpur   KUL  3.105824  101.666428
# 273     59700  Kuala Lumpur   KUL  3.143822  101.689590
# 274     59800  Kuala Lumpur   KUL  3.143822  101.689590
# 275     59990  Kuala Lumpur   KUL  3.117759  101.667549
# 276     60000  Kuala Lumpur   KUL  3.152098  101.626442
#
# [277 rows x 5 columns]

# %%
# joining longitude and Latitude for ease of reverse geocode
df['LongLat'] = df[df.columns[3:]].apply(lambda x: ','.join(x.dropna().astype(str)),axis=1)
df
# Out:
#      POSTCODE          CITY STATE  Latitude   Longitude  \
# 0       50000  Kuala Lumpur   KUL  3.142934  101.696373
# 1       50050  Kuala Lumpur   KUL  3.147618  101.696281
# 2       50088  Kuala Lumpur   KUL  3.155141  101.711540
# 3       50100  Kuala Lumpur   KUL  3.152210  101.696510
# 4       50150  Kuala Lumpur   KUL  3.191760  101.658691
# ..        ...           ...   ...       ...         ...
# 272     59200  Kuala Lumpur   KUL  3.105824  101.666428
# 273     59700  Kuala Lumpur   KUL  3.143822  101.689590
# 274     59800  Kuala Lumpur   KUL  3.143822  101.689590
# 275     59990  Kuala Lumpur   KUL  3.117759  101.667549
# 276     60000  Kuala Lumpur   KUL  3.152098  101.626442
#
#                                    LongLat
# 0    3.1429340839385986,101.69637298583984
# 1     3.147618055343628,101.69628143310547
# 2    3.1551411151885986,101.71154022216797
# 3      3.152209997177124,101.6965103149414
# 4       3.1917600631713867,101.65869140625
# ..                                     ...
# 272  3.1058239936828613,101.66642761230469
# 273   3.143821954727173,101.68959045410156
# 274   3.143821954727173,101.68959045410156
# 275  3.1177589893341064,101.66754913330078
# 276   3.1520979404449463,101.6264419555664
#
# [277 rows x 6 columns]

# %% [markdown]
# After getting Longitude and Latitude, we would like to increase the accuracy of the address given earlier. thus we do a reverse geocode based on Latitude and Longitude to find the location.

# %%
from bingmaps.apiservices import LocationByPoint
Location =[]
for i in df.LongLat:
    coordinate= i
    data1 = {'point': coordinate,'includeEntityTypes': 'Address','key': bmkey}
    loc_by_point = LocationByPoint(data1)
    Location0 = [loc_by_point.get_address]
    try:
        Location1 = Location0[0][0]
    except:
        Location1 = "NA"
    try:
        Location2 = Location1['intersection'].get('displayName')
    except:
        Location2 = "NA"
    print(Location2)
    Location += [Location2]
# Out:
# Jalan Tun H.S. Lee and Jalan Sultan
# Jalan Tun Tan Siew Tin, between Medan Pasar Besar and Jalan Tun H.S. Lee
# NA
# Lorong Tuanku Abdul Rahman Kiri 2 and Lorong Tuanku Abdul Rahman
# NA
# Jalan Imbi and Jalan Sultan Ismail
# NA
# NA
# Lorong Kolam Air 7 and Jalan Kolam Air 6
# Jalan Pangkur, between Jalan Cemur and Jalan 1/68D
# Jalan Ampang, between Jalan Binjai and Jalan Tun Razak
# NA
# Jalan Tun Sambanthan and Jalan Stesen Sentral 5
# Jalan Serene Kiara 8 and Jalan Serene Kiara 6
# Lorong Derumun and Persiaran Derumun
# Jalan Syed Putra and Jalan Istana
# Jalan Tuanku Abdul Rahman, between Jalan Mara and Jalan Dang Wangi
# Jalan Raja Laut and Jalan Sri Amar
# NA
# NA
# NA
# Jalan Gereja, between Jalan Melaka and Lorong Ampang
# Jalan Tangsi, between Jalan Parlimen and Jalan Kinabalu
# Jalan Kampung Attap, between Jalan Tuba and Jalan Manau
# Jalan Merpati, between Jalan Tuanku Abdul Rahman and Jalan Raja Laut
# NA
# NA
# NA
# Jalan Semantan, between E23 and Lebuhraya Sprint
# Jalan Ampang, between Jalan Ampang Tengah and Jalan Jelatek
# Jalan 1/68F and Jalan Taman U-Thant
# NA
# NA
# NA
# NA
# NA
# Jalan Sri Hartamas 1, between Persiaran Nusantara and Persiaran Dutamas
# NA
# Jalan Kampar, between Jalan Tun Razak and Jalan Sentul Manis
# Jalan Loke Yew, between Jalan Chan Sow Lin and Jalan Metro Pudu
# Jalan Padang Tembak, between Jalan Laksamana and Jalan Kementah
# NA
# NA
# Jalan Pahang and Jalan Taiping
# Jalan Sultan Hishamuddin and Jalan Stesen Sentral
# NA
# Jalan Tun Razak and Jalan 1/65A
# Jalan Sultan Yahya Petra, between Jalan Perumahan Gurney and Jalan Maktab
# Jalan Perumahan Gurney, between Jalan Maktab 4 and Jalan Sultan Yahya Petra
# NA
# Jalan Metro Pudu, between Jalan Metro Pudu 2 and Jalan Metro Pudu 1
# Jalan Doktor Latiff, between Jalan Masjid Hospital and Jalan Raja Muda Abdul Aziz
# Jalan Pahang, between Jalan Sultan Azlan Shah and Jalan Masjid Hospital
# Lorong Kolam Air 8 and Jalan Keruing
# NA
# NA
# NA
# Jalan Raja Laut and Jalan Bunus
# NA
# NA
# Lorong 16/10A and Persiaran Bernas
# NA
# NA
# Lorong Dungun, between Jalan Dungun and Changkat Semantan
# Jalan Merpati, between Jalan Raja Laut and Jalan Tuanku Abdul Rahman
# NA
# Jalan Chagar and Jalan Tiong Nam
# Lebuhraya Persekutuan and Mid Valley Expressway
# NA
# Jalan Kinabalu, between Bulatan Hishamuddin and Bulatan Hishamuddin
# NA
# NA
# NA
# NA
# Jalan Tekpi, between Jalan Padang Tembak and Jalan Chenderik
# NA
# NA
# NA
# NA
# NA
# Jalan Cenderasari, between Jalan Tugu and Jalan Lembah
# NA
# Jalan Damanlela and Jalan Damansuria
# Jalan Tasik Selatan 4, between Jalan Tasik Selatan 3 and Jalan Tasik Selatan 3
# NA
# Jalan Sultan Hishamuddin, between Leboh Pasar Besar and Jalan Kinabalu
# Jalan Tun Razak and Jalan Ampang
# NA
# NA
# Jalan Bukit Kiara, between Persiaran Bukit Kiara and Persiaran Bukit Kiara
# Jalan Dwitasik 1, between Jalan Dwitasik and Jalan Sri Permaisuri
# NA
# Jalan Damanlela and Jalan Damansuria
# Jalan Tun Tan Cheng Lock, between Jalan Petaling and Jalan Tun H.S. Lee
# NA
# Jalan Kilat, between Jalan Ranau and Jalan Bangsar
# NA
# NA
# NA
# NA
# NA
# NA
# Jalan Stesen Sentral 2, between Jalan Stesen Sentral and Jalan Stesen Sentral
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# Leboh Pasar Besar, between Jalan Mahkamah Persekutuan and Jalan Sultan Hishamuddin
# NA
# NA
# Jalan Parlimen, between Bulatan Dato Onn and Jalan Tangsi
# NA
# NA
# Jalan Hussein, between Jalan Abdul Rahman Idris and Jalan Raja Hussein 2
# NA
# NA
# NA
# Jalan Putra, between Jalan Tun Ismail and Jalan 1/64D
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# Jalan Jejaka, between Jalan Jejaka 1 and Jalan Cheras
# NA
# NA
# Jalan 15/26 and Jalan 14/26
# Jalan Sultan Ismail, between Jalan Raja Abdullah and Jalan Doraisamy
# NA
# NA
# NA
# NA
# NA
# Lorong Hang Jebat and Jalan Tun Tan Cheng Lock
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# Jalan Kuching and Jalan Dato Onn
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# Jalan Tun Razak, between Lorong Kuda and Lorong Kuda
# Jalan Sentul Impian and Jalan Sentul Endah
# NA
# Jalan 6/38D and Jalan 8/38D
# NA
# NA
# Jalan 7/33B, between Jalan 33B and Jalan 33B
# NA
# Jalan Manja 4 and Jalan Burung Hantu
# Lorong Balai Raya and Jalan Sungai
# NA
# NA
# Jalan Rejang 1, between Jalan Seri Rejang 5 and Jalan Seri Rejang 3
# NA
# NA
# NA
# NA
# Lorong Gurney, between Jalan San Ah Wing and Jalan Sultan Yahya Petra
# NA
# Jalan U-Thant and Lingkungan U-Thant
# Jalan Pria 1, between Jalan Pria 8 and Jalan Pria
# Jalan Kelian, between Jalan Lombong and Jalan Palong
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# NA
# Jalan 5/89A and Jalan Sekilau
# NA
# Jalan Radin Bagus and Jalan Radin Bagus 6
# Lorong Ikan Emas, between Jalan Ikan Emas and Jalan Ikan Emas
# NA
# NA
# Jalan Teluk Batu, between Jalan Teluk Pulai and Lengkongan Jenjarom
# NA
# NA
# NA
# NA
# Lorong Maarof, between Jalan Bukit Bangsar and Jalan Maarof
# NA
# Jalan Pantai Permai 12 and Jalan Pantai Permai 7
# NA
# NA
# NA
# Medan Athinahapan 2 and Medan Athinahapan 1

# %%
df5 = pd.DataFrame (Location,columns=['Location']) #convert the list to dataframe
df5.shape
# Out:
# (277, 1)

# %%
print(df.shape,df5.shape)
df =df.join(df5) #join the location with existing dataframe
df.head()
print(df.shape)
# Out:
# (277, 6) (277, 1)
# (277, 7)

# %%
df = df[df.Location != 'NA'] #drop NA in Location
#df = df.drop_duplicates(subset=['Location']) #drop duplicate Location
df.reset_index(drop=True, inplace=True) #reset index
df
# Out:
#     POSTCODE          CITY STATE  Latitude   Longitude  \
# 0      50000  Kuala Lumpur   KUL  3.142934  101.696373
# 1      50050  Kuala Lumpur   KUL  3.147618  101.696281
# 2      50100  Kuala Lumpur   KUL  3.152210  101.696510
# 3      50200  Kuala Lumpur   KUL  3.143709  101.711952
# 4      50350  Kuala Lumpur   KUL  3.173631  101.685585
# ..       ...           ...   ...       ...         ...
# 74     57100  Kuala Lumpur   KUL  3.115582  101.721519
# 75     58000  Kuala Lumpur   KUL  3.114526  101.682671
# 76     59000  Kuala Lumpur   KUL  3.128453  101.675003
# 77     59200  Kuala Lumpur   KUL  3.105824  101.666428
# 78     60000  Kuala Lumpur   KUL  3.152098  101.626442
#
#                                   LongLat  \
# 0   3.1429340839385986,101.69637298583984
# 1    3.147618055343628,101.69628143310547
# 2     3.152209997177124,101.6965103149414
# 3   3.1437089443206787,101.71195220947266
# 4    3.173630952835083,101.68558502197266
# ..                                    ...
# 74    3.11558198928833,101.72151947021484
# 75  3.1145260334014893,101.68267059326172
# 76   3.128453016281128,101.67500305175781
# 77  3.1058239936828613,101.66642761230469
# 78   3.1520979404449463,101.6264419555664
#
#                                              Location
# 0                 Jalan Tun H.S. Lee and Jalan Sultan
# 1   Jalan Tun Tan Siew Tin, between Medan Pasar Be...
# 2   Lorong Tuanku Abdul Rahman Kiri 2 and Lorong T...
# 3                  Jalan Imbi and Jalan Sultan Ismail
# 4            Lorong Kolam Air 7 and Jalan Kolam Air 6
# ..                                                ...
# 74  Lorong Ikan Emas, between Jalan Ikan Emas and ...
# 75  Jalan Teluk Batu, between Jalan Teluk Pulai an...
# 76  Lorong Maarof, between Jalan Bukit Bangsar and...
# 77   Jalan Pantai Permai 12 and Jalan Pantai Permai 7
# 78        Medan Athinahapan 2 and Medan Athinahapan 1
#
# [79 rows x 7 columns]

# %% [markdown]
# Final list has been trimmed down to 78 rows only!

# %% [markdown]
# ### 4. Visualize the Location in Folium

# %%
address = 'Kuala Lumpur, MY'

geolocator = Nominatim(user_agent="my_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Kuala Lumput are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Kuala Lumput are 3.1516964, 101.6942371.

# %%
# create map of Toronto using latitude and longitude values
map_KL = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, location, postcode in zip(df['Latitude'], df['Longitude'], df['Location'], df['POSTCODE']):
# The zip() function returns a zip object, 
# which is an iterator of tuples where the first item in each passed iterator is paired together, 
# and then the second item in each passed iterator are paired together etc.
# If the passed iterators have different lengths, the iterator with the least items decides the length of the new iterator.
    label = '{}, {}'.format(location, postcode)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_KL)  
    
map_KL
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 5. Export to CSV

# %%
df.to_csv(r'C:\Users\xxxx\Desktop\KL_Main_Area.csv')
print("Export Completed")
# Out:
# Export Completed
